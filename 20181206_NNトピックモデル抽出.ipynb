# %%
import codecs as cd
import gensim
from janome.tokenizer import Tokenizer
from gensim import corpora, models, similarities
# Out:
# C:\Anaconda3\envs\tf_keras\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
filename = 'data.txt'
file = cd.open(filename,  'r', 'utf-8')
lines = file.readlines()

t = Tokenizer()
wvs = []

# %%
for i, line in enumerate(lines):
    # 一つのページのワードのベクトル
    word_vector = []
    # 短すぎる場合は無視
    if len(line)<30:
        continue
        # 記号以外はベクトル作成
    else:
        tokens = t.tokenize(line)
        
    for token in tokens:
        if token.part_of_speech[:2] == '名詞' or token.part_of_speech[:2] == '動詞':
            word_vector += [token.base_form]

    # データを連結
    wvs += [word_vector]

# %%
# 辞書作成
dictionary = corpora.Dictionary(wvs)
dictionary.filter_extremes(no_below=2, no_above=0.3)
dictionary.save_as_text('dict.txt')

# コーパスを作成
corpus = [dictionary.doc2bow(text) for text in wvs]
corpora.MmCorpus.serialize('cop.mm', corpus)

# %%
dictionary = gensim.corpora.Dictionary.load_from_text('dict.txt')
corpus = corpora.MmCorpus('cop.mm')

# %%
topic_N = 40
lda = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=topic_N, id2word=dictionary)

for i in range(topic_N):
    print('TOPIC:', i, '__', lda.print_topic(i))
# Out:
# TOPIC: 0 __ 0.019*"計算" + 0.019*"条件" + 0.017*"膜" + 0.015*"状態" + 0.015*"値" + 0.012*"神経" + 0.011*"加工" + 0.010*"化" + 0.010*"位置" + 0.010*"工作"
# TOPIC: 1 __ 0.028*"０" + 0.024*"前記" + 0.016*"値" + 0.014*"プロセス" + 0.013*"特徴" + 0.012*"推定" + 0.012*"情報" + 0.011*"量" + 0.011*"モデル" + 0.010*"計算"
# TOPIC: 2 __ 0.033*"認識" + 0.029*"音声" + 0.027*"溶接" + 0.022*"文字" + 0.021*"ノード" + 0.017*"用" + 0.017*"生成" + 0.014*"検出" + 0.014*"合成" + 0.013*"システム"
# TOPIC: 3 __ 0.070*"評価" + 0.028*"色" + 0.022*"値" + 0.016*"レベル" + 0.012*"計画" + 0.012*"コンテンツ" + 0.012*"パラメータ" + 0.011*"記述" + 0.011*"ニューラルネット" + 0.010*"関連"
# TOPIC: 4 __ 0.034*"ニューロン" + 0.025*"信号" + 0.020*"５" + 0.018*"０" + 0.013*"層" + 0.011*"素子" + 0.010*"ニューラルネットワーク" + 0.009*"重み" + 0.009*"４" + 0.008*"接続"
# TOPIC: 5 __ 0.040*"値" + 0.016*"信号" + 0.013*"パラメータ" + 0.012*"特徴" + 0.011*"処理" + 0.011*"化" + 0.011*"色" + 0.009*"関数" + 0.008*"予測" + 0.008*"モデル"
# TOPIC: 6 __ 0.028*"６" + 0.026*"０" + 0.019*"ベクトル" + 0.018*"４" + 0.012*"８" + 0.011*"記憶" + 0.011*"５" + 0.010*"サブ" + 0.010*"ネットワーク" + 0.010*"検出"
# TOPIC: 7 __ 0.019*"音響" + 0.019*"モデル" + 0.015*"量" + 0.014*"信号" + 0.014*"特徴" + 0.013*"値" + 0.013*"制御" + 0.013*"決定" + 0.012*"ニューラルネットワーク" + 0.011*"ガス"
# TOPIC: 8 __ 0.024*"状態" + 0.022*"情報" + 0.015*"化" + 0.013*"算出" + 0.011*"値" + 0.009*"変化" + 0.008*"活性" + 0.008*"遺伝子" + 0.008*"システム" + 0.007*"位置"
# TOPIC: 9 __ 0.026*"制御" + 0.024*"システム" + 0.024*"動作" + 0.014*"情報" + 0.012*"者" + 0.010*"センサ" + 0.010*"受信" + 0.009*"化" + 0.008*"５" + 0.008*"せる"
# TOPIC: 10 __ 0.033*"信号" + 0.023*"０" + 0.015*"ステップ" + 0.015*"状態" + 0.013*"パラメータ" + 0.012*"モデル" + 0.011*"前記" + 0.009*"４" + 0.008*"生成" + 0.008*"ロボット"
# TOPIC: 11 __ 0.047*"０" + 0.022*"処理" + 0.015*"制御" + 0.015*"４" + 0.013*"検出" + 0.012*"情報" + 0.011*"画像" + 0.010*"物体" + 0.010*"６" + 0.009*"５"
# TOPIC: 12 __ 0.021*"前記" + 0.017*"値" + 0.012*"システム" + 0.011*"発明" + 0.010*"セット" + 0.009*"(" + 0.009*"分類" + 0.009*"個体" + 0.009*")" + 0.008*"特徴"
# TOPIC: 13 __ 0.039*"情報" + 0.023*"システム" + 0.020*"生成" + 0.017*"制御" + 0.013*"前記" + 0.012*"処理" + 0.010*"予測" + 0.009*"構成" + 0.009*"パターン" + 0.009*"発明"
# TOPIC: 14 __ 0.028*"測定" + 0.023*"値" + 0.017*"前記" + 0.012*"光" + 0.011*"エネルギー" + 0.010*"材料" + 0.009*"サンプル" + 0.008*"スペクトル" + 0.007*"ベクトル" + 0.007*"表示"
# TOPIC: 15 __ 0.028*"信号" + 0.027*"０" + 0.024*"ニューラルネットワーク" + 0.022*"制御" + 0.013*"時間" + 0.012*"開示" + 0.011*"動的" + 0.010*"４" + 0.009*"いる" + 0.009*"教師"
# TOPIC: 16 __ 0.039*"画像" + 0.027*"ニューラルネットワーク" + 0.019*"処理" + 0.018*"前記" + 0.013*"ベクトル" + 0.011*"生成" + 0.010*"領域" + 0.010*"カテゴリ" + 0.009*"値" + 0.009*"セット"
# TOPIC: 17 __ 0.027*"処理" + 0.026*"０" + 0.025*"回路" + 0.025*"画像" + 0.023*"前記" + 0.017*"信号" + 0.015*"ニューラルネットワーク" + 0.015*"演算" + 0.013*"素子" + 0.013*"４"
# TOPIC: 18 __ 0.026*"電子" + 0.024*"サポート" + 0.020*"応答" + 0.019*"顧客" + 0.016*"判断" + 0.015*"発光" + 0.015*"アプリケーション" + 0.014*"ユニット" + 0.013*"データベース" + 0.012*"アクセス"
# TOPIC: 19 __ 0.017*"化" + 0.017*"診断" + 0.013*"システム" + 0.012*"性" + 0.011*"機能" + 0.011*"１つ" + 0.010*"測定" + 0.010*"分析" + 0.009*"組織" + 0.009*"ターゲット"
# TOPIC: 20 __ 0.034*"信号" + 0.031*"画像" + 0.015*"生成" + 0.013*"処理" + 0.012*"１つ" + 0.011*"ニューラルネットワーク" + 0.009*"オーディオ" + 0.009*"システム" + 0.008*"よう" + 0.008*"特徴"
# TOPIC: 21 __ 0.063*"予測" + 0.030*"モデル" + 0.022*"値" + 0.022*"０" + 0.020*"細胞" + 0.017*"振動" + 0.010*"ステップ" + 0.009*"算出" + 0.009*"判定" + 0.008*"音声"
# TOPIC: 22 __ 0.030*"０" + 0.021*"層" + 0.016*"システム" + 0.014*"１つ" + 0.013*"ニューラルネットワーク" + 0.012*"性" + 0.011*"ニューロン" + 0.010*"処理" + 0.010*"結合" + 0.010*"られる"
# TOPIC: 23 __ 0.024*"値" + 0.023*"運動" + 0.014*"層" + 0.014*"パターン" + 0.011*"重み" + 0.011*"予測" + 0.010*"アセンブリ" + 0.010*"患者" + 0.010*"よう" + 0.009*"処理"
# TOPIC: 24 __ 0.022*"プロセス" + 0.014*"値" + 0.014*"システム" + 0.010*"処理" + 0.010*"モデル" + 0.010*"特性" + 0.009*"化" + 0.008*"生成" + 0.008*"いる" + 0.008*"可能"
# TOPIC: 25 __ 0.029*"情報" + 0.013*"性" + 0.013*"複合" + 0.013*"仮想" + 0.012*"特徴" + 0.012*"体" + 0.012*"診断" + 0.012*"間" + 0.011*"オブジェクト" + 0.010*"設計"
# TOPIC: 26 __ 0.020*"特徴" + 0.018*"値" + 0.016*"量" + 0.015*"推定" + 0.013*"情報" + 0.012*"音声" + 0.009*"算出" + 0.009*"判定" + 0.008*"製品" + 0.008*"度"
# TOPIC: 27 __ 0.044*"画像" + 0.012*"決定" + 0.010*"４" + 0.010*"顔" + 0.010*"パラメータ" + 0.010*"値" + 0.009*"認識" + 0.009*"システム" + 0.009*"ユーザ" + 0.009*"時"
# TOPIC: 28 __ 0.031*"予測" + 0.017*"情報" + 0.014*"値" + 0.014*"画像" + 0.012*"ニューラルネットワーク" + 0.010*"パラメータ" + 0.010*"時" + 0.010*"層" + 0.009*"モデル" + 0.009*"系列"
# TOPIC: 29 __ 0.030*"量" + 0.030*"信号" + 0.026*"電力" + 0.020*"予測" + 0.018*"前記" + 0.017*"値" + 0.012*"回路" + 0.011*"発電" + 0.011*"化" + 0.010*"制御"
# TOPIC: 30 __ 0.034*"画像" + 0.024*"特徴" + 0.019*"前記" + 0.014*"０" + 0.013*"組立" + 0.011*"量" + 0.010*"生成" + 0.009*"変換" + 0.009*"情報" + 0.008*"検出"
# TOPIC: 31 __ 0.056*"０" + 0.022*"システム" + 0.018*"モジュール" + 0.016*"パターン" + 0.013*"ステップ" + 0.012*"４" + 0.012*"検出" + 0.009*"状態" + 0.009*"車両" + 0.008*"情報"
# TOPIC: 32 __ 0.021*"状態" + 0.018*"値" + 0.017*"変数" + 0.017*"推定" + 0.015*"情報" + 0.015*"者" + 0.011*"波形" + 0.011*"予測" + 0.010*"算出" + 0.008*"類似"
# TOPIC: 33 __ 0.016*"使用" + 0.013*"値" + 0.013*"論理" + 0.013*"信号" + 0.013*"通信" + 0.012*"遠隔" + 0.011*"システム" + 0.011*"モニタリング" + 0.011*"可能" + 0.009*"測定"
# TOPIC: 34 __ 0.039*"値" + 0.029*"ベクトル" + 0.019*"動作" + 0.018*"ニューラルネットワーク" + 0.016*"層" + 0.012*"分類" + 0.011*"モデル" + 0.011*"機器" + 0.010*"判定" + 0.009*"設定"
# TOPIC: 35 __ 0.030*"情報" + 0.015*"０" + 0.014*"要素" + 0.012*"推定" + 0.011*"モデル" + 0.009*"楽曲" + 0.009*"変換" + 0.008*"４" + 0.008*"対象" + 0.008*"画像"
# TOPIC: 36 __ 0.033*"画像" + 0.025*"処理" + 0.021*"領域" + 0.014*"検出" + 0.012*"物" + 0.010*"ニューラルネットワーク" + 0.009*"生成" + 0.009*"１つ" + 0.009*"ステップ" + 0.008*"システム"
# TOPIC: 37 __ 0.075*"画像" + 0.024*"温度" + 0.022*"０" + 0.013*"撮像" + 0.012*"像" + 0.011*"監視" + 0.010*"発症" + 0.010*"せる" + 0.010*"値" + 0.010*"火災"
# TOPIC: 38 __ 0.071*"前記" + 0.019*"スパイク" + 0.016*"量" + 0.015*"空気" + 0.014*"処理" + 0.012*"情報" + 0.011*"非線形" + 0.010*"ステップ" + 0.009*"放出" + 0.009*"."
# TOPIC: 39 __ 0.026*"制御" + 0.021*"画像" + 0.017*"値" + 0.014*"信号" + 0.013*"サンプル" + 0.011*"システム" + 0.010*"測定" + 0.010*"特性" + 0.010*"ステップ" + 0.010*"者"
