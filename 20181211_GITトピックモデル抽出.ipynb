# %%
import codecs as cd
import gensim
from janome.tokenizer import Tokenizer
from gensim import corpora, models, similarities
# Out:
# C:\Anaconda3\envs\tf_keras\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
filename = 'ZIT_PATENT.txt'
file = cd.open(filename,  'r', 'utf-8')
lines = file.readlines()

t = Tokenizer()
wvs = []

# %%
for i, line in enumerate(lines):
    # 一つのページのワードのベクトル
    word_vector = []
    # 短すぎる場合は無視
    if len(line)<30:
        continue
        # 記号以外はベクトル作成
    else:
        tokens = t.tokenize(line)
        
    for token in tokens:
        if token.part_of_speech[:2] == '名詞' or token.part_of_speech[:2] == '動詞':
            word_vector += [token.base_form]

    # データを連結
    wvs += [word_vector]

# %%
# 辞書作成
dictionary = corpora.Dictionary(wvs)
dictionary.filter_extremes(no_below=2, no_above=0.3)
dictionary.save_as_text('dict.txt')

# コーパスを作成
corpus = [dictionary.doc2bow(text) for text in wvs]
corpora.MmCorpus.serialize('cop.mm', corpus)

# %%
dictionary = gensim.corpora.Dictionary.load_from_text('dict.txt')
corpus = corpora.MmCorpus('cop.mm')

# %%
topic_N = 40
lda = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=topic_N, id2word=dictionary)

for i in range(topic_N):
    print('TOPIC:', i, '__', lda.print_topic(i))
# Out:
# TOPIC: 0 __ 0.045*"前記" + 0.013*"手段" + 0.013*"決済" + 0.013*"ステップ" + 0.011*"位置" + 0.011*"車両" + 0.011*"処理" + 0.010*"画像" + 0.010*"出力" + 0.009*"電子"
# TOPIC: 1 __ 0.027*"端末" + 0.018*"制御" + 0.018*"５" + 0.017*"４" + 0.015*"通信" + 0.015*"手段" + 0.014*"判定" + 0.012*"機器" + 0.010*"携帯" + 0.010*"送信"
# TOPIC: 2 __ 0.045*"前記" + 0.019*"車両" + 0.016*"メイク" + 0.014*"状態" + 0.013*"量" + 0.011*"制御" + 0.010*"通信" + 0.009*"作業" + 0.008*"特定" + 0.008*"機"
# TOPIC: 3 __ 0.020*"通信" + 0.018*"前記" + 0.016*"表示" + 0.013*"車両" + 0.012*"手段" + 0.011*"使用" + 0.011*"制御" + 0.011*"通知" + 0.010*"電力" + 0.010*"者"
# TOPIC: 4 __ 0.027*"複数" + 0.020*"値" + 0.018*"前記" + 0.016*"表示" + 0.012*"検出" + 0.012*"６" + 0.011*"５" + 0.010*"得る" + 0.009*"制御" + 0.008*"１つ"
# TOPIC: 5 __ 0.018*"ユーザ" + 0.014*"表示" + 0.012*"イベント" + 0.012*"商品" + 0.010*"受信" + 0.010*"所定" + 0.009*"生成" + 0.009*"処理" + 0.009*"４" + 0.009*"複数"
# TOPIC: 6 __ 0.019*"画像" + 0.015*"前記" + 0.015*"制御" + 0.014*"処理" + 0.013*"照明" + 0.012*"機器" + 0.012*"移動" + 0.010*"表示" + 0.010*"撮像" + 0.010*"４"
# TOPIC: 7 __ 0.048*"ユーザ" + 0.017*"通信" + 0.014*"機器" + 0.013*"５" + 0.012*"端末" + 0.011*"状態" + 0.011*"４" + 0.010*"健康" + 0.010*"ため" + 0.009*"行動"
# TOPIC: 8 __ 0.022*"前記" + 0.013*"位置" + 0.012*"制御" + 0.012*"ため" + 0.011*"ユーザ" + 0.011*"端末" + 0.010*"複数" + 0.009*"よう" + 0.009*"管理" + 0.008*"構成"
# TOPIC: 9 __ 0.015*"分析" + 0.015*"位置" + 0.013*"度" + 0.012*"製品" + 0.011*"４" + 0.010*"ため" + 0.010*"算出" + 0.009*"表示" + 0.009*"前記" + 0.008*"移動"
# TOPIC: 10 __ 0.028*"手段" + 0.020*"端末" + 0.020*"前記" + 0.019*"ユーザ" + 0.013*"車両" + 0.011*"判定" + 0.009*"サーバ" + 0.009*"画像" + 0.009*"算出" + 0.009*"複数"
# TOPIC: 11 __ 0.021*"電子" + 0.016*"ユーザ" + 0.013*"電気" + 0.013*"発生" + 0.012*"記憶" + 0.012*"ゲーム" + 0.011*"ため" + 0.011*"測定" + 0.010*"端末" + 0.010*"刺激"
# TOPIC: 12 __ 0.029*"ユーザ" + 0.014*"送信" + 0.014*"通信" + 0.013*"記憶" + 0.011*"受信" + 0.011*"４" + 0.011*"端末" + 0.010*"走行" + 0.010*"自動" + 0.010*"車両"
# TOPIC: 13 __ 0.034*"前記" + 0.017*"管理" + 0.013*"４" + 0.012*"者" + 0.012*"遊技" + 0.012*"処理" + 0.011*"識別" + 0.010*"複数" + 0.010*"センサ" + 0.010*"対象"
# TOPIC: 14 __ 0.024*"前記" + 0.016*"記憶" + 0.015*"管理" + 0.015*"送信" + 0.013*"利用" + 0.012*"遊技" + 0.012*"ユーザ" + 0.012*"機" + 0.011*"車両" + 0.011*"受信"
# TOPIC: 15 __ 0.030*"者" + 0.022*"運転" + 0.015*"管理" + 0.013*"利用" + 0.010*"前記" + 0.010*"場合" + 0.009*"通信" + 0.009*"いる" + 0.008*"作業" + 0.008*"判定"
# TOPIC: 16 __ 0.014*"推定" + 0.014*"度" + 0.013*"検出" + 0.013*"送信" + 0.011*"商品" + 0.011*"脈拍" + 0.011*"事象" + 0.010*"的" + 0.010*"複数" + 0.009*"計測"
# TOPIC: 17 __ 0.017*"ユーザ" + 0.015*"車両" + 0.012*"制御" + 0.012*"いる" + 0.010*"ため" + 0.010*"者" + 0.009*"よう" + 0.008*"前記" + 0.008*"送信" + 0.008*"特定"
# TOPIC: 18 __ 0.031*"前記" + 0.022*"施設" + 0.019*"状態" + 0.017*"処理" + 0.017*"利用" + 0.016*"管理" + 0.015*"制御" + 0.012*"一" + 0.012*"商品" + 0.011*"端末"
# TOPIC: 19 __ 0.032*"前記" + 0.019*"制御" + 0.017*"車両" + 0.017*"位置" + 0.015*"処理" + 0.015*"端末" + 0.014*"表示" + 0.013*"手段" + 0.011*"者" + 0.010*"特定"
# TOPIC: 20 __ 0.012*"複数" + 0.011*"ユーザ" + 0.010*"処理" + 0.010*"設定" + 0.010*"画像" + 0.010*"管理" + 0.010*"ため" + 0.009*"表示" + 0.009*"記憶" + 0.009*"値"
# TOPIC: 21 __ 0.022*"端末" + 0.019*"管理" + 0.016*"表示" + 0.015*"ユーザ" + 0.014*"位置" + 0.013*"者" + 0.013*"画像" + 0.013*"４" + 0.012*"送信" + 0.011*"状態"
# TOPIC: 22 __ 0.028*"前記" + 0.014*"送信" + 0.014*"サーバ" + 0.013*"手段" + 0.013*"商品" + 0.011*"センサ" + 0.011*"受信" + 0.011*"記憶" + 0.010*"者" + 0.009*"登録"
# TOPIC: 23 __ 0.034*"作業" + 0.021*"前記" + 0.016*"画像" + 0.012*"受信" + 0.011*"送信" + 0.011*"位置" + 0.011*"行う" + 0.009*"生成" + 0.009*"対象" + 0.009*"者"
# TOPIC: 24 __ 0.021*"判定" + 0.017*"手段" + 0.017*"処理" + 0.016*"対象" + 0.013*"商品" + 0.012*"記憶" + 0.011*"モデル" + 0.010*"者" + 0.009*"送信" + 0.009*"実行"
# TOPIC: 25 __ 0.017*"行動" + 0.015*"サービス" + 0.014*"車両" + 0.013*"者" + 0.012*"前記" + 0.011*"ネットワーク" + 0.010*"接続" + 0.010*"アクセス" + 0.009*"５" + 0.009*"デバイス"
# TOPIC: 26 __ 0.021*"車両" + 0.019*"送信" + 0.017*"４" + 0.014*"前記" + 0.012*"制御" + 0.012*"複数" + 0.011*"者" + 0.011*"受信" + 0.011*"手段" + 0.011*"画像"
# TOPIC: 27 __ 0.026*"端末" + 0.020*"送信" + 0.016*"記憶" + 0.014*"通信" + 0.012*"車両" + 0.012*"受信" + 0.012*"表示" + 0.010*"者" + 0.010*"状態" + 0.010*"対象"
# TOPIC: 28 __ 0.038*"制御" + 0.018*"手段" + 0.014*"機器" + 0.014*"運転" + 0.014*"前記" + 0.012*"状態" + 0.011*"対象" + 0.010*"検知" + 0.010*"６" + 0.009*"者"
# TOPIC: 29 __ 0.028*"遊技" + 0.021*"サーバ" + 0.018*"管理" + 0.017*"データベース" + 0.016*"端末" + 0.016*"認証" + 0.016*"記憶" + 0.015*"特定" + 0.014*"監視" + 0.013*"ターゲット"
# TOPIC: 30 __ 0.024*"端末" + 0.019*"受信" + 0.017*"機" + 0.014*"４" + 0.014*"者" + 0.012*"車両" + 0.011*"要求" + 0.011*"５" + 0.011*"位置" + 0.010*"管理"
# TOPIC: 31 __ 0.020*"センサ" + 0.017*"５" + 0.015*"状態" + 0.015*"画像" + 0.011*"４" + 0.011*"位置" + 0.011*"管理" + 0.011*"端末" + 0.011*"走行" + 0.010*"生成"
# TOPIC: 32 __ 0.048*"前記" + 0.026*"手段" + 0.015*"者" + 0.013*"画像" + 0.013*"表示" + 0.012*"判定" + 0.011*"記憶" + 0.010*"撮像" + 0.009*"管理" + 0.009*"量"
# TOPIC: 33 __ 0.020*"端末" + 0.017*"受信" + 0.016*"ユーザ" + 0.014*"送信" + 0.013*"者" + 0.009*"商品" + 0.009*"管理" + 0.009*"複数" + 0.008*"サーバ" + 0.008*"ため"
# TOPIC: 34 __ 0.031*"サーバ" + 0.022*"位置" + 0.018*"端末" + 0.015*"受信" + 0.013*"通信" + 0.013*"制御" + 0.013*"タグ" + 0.012*"送信" + 0.012*"車両" + 0.012*"者"
# TOPIC: 35 __ 0.018*"前記" + 0.016*"検出" + 0.013*"機器" + 0.013*"特定" + 0.012*"記憶" + 0.012*"ユーザ" + 0.011*"処理" + 0.011*"管理" + 0.010*"端末" + 0.010*"判定"
# TOPIC: 36 __ 0.028*"５" + 0.015*"測定" + 0.013*"地点" + 0.013*"４" + 0.012*"特徴" + 0.011*"需要" + 0.011*"管理" + 0.010*"送信" + 0.010*"ユーザ" + 0.009*"グラフ"
# TOPIC: 37 __ 0.022*"前記" + 0.016*"ユーザ" + 0.014*"者" + 0.014*"状態" + 0.014*"電力" + 0.013*"自動" + 0.012*"使用" + 0.011*"遊技" + 0.011*"利用" + 0.011*"管理"
# TOPIC: 38 __ 0.032*"車両" + 0.023*"者" + 0.019*"利用" + 0.015*"端末" + 0.015*"状態" + 0.014*"運転" + 0.010*"位置" + 0.010*"記憶" + 0.010*"制御" + 0.009*"前記"
# TOPIC: 39 __ 0.015*"方法" + 0.013*"検知" + 0.011*"複数" + 0.011*"特定" + 0.010*"機器" + 0.010*"健康" + 0.010*"使用" + 0.009*"ステップ" + 0.009*"員" + 0.009*"ため"
